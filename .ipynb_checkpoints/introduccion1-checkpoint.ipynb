# %% [markdown]
# # Intrducción a Python
#
# Python es un lenguaje de programación de alto nivel. <br>
# Orientado a objetos

# %%
#esto es un comentario y se va a imprimir "hola mundo Python"
# imprimir (Hola Mundo Python) lo que está dentro de las comillas se llama cadena de caracteres o string
print("Hola Mundo Python")
# Out:
# Hola Mundo Python

# %%
print ("Gabriel")
# Out:
# Gabriel
